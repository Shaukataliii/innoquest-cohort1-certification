# %%
import os
os.chdir('../..')

# %%
os.getcwd()
# Out:
# 'd:\\Shaukat ali khan\\programming\\courses\\Innovista-etech-bootcamp\\assignments\\machine-learning\\1\\notebooks'

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/AmesHousing.csv')
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
df.shape
# Out:
# (2930, 82)

# %%
df.isnull().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
rows_count = df.shape[0]
for col in df.columns:
    null_count = df[col].isnull().sum()
    print(f'{col}: {null_count} nulls i.e. {round(null_count/rows_count * 100, 2)}%')
# Out:
# Order: 0 nulls i.e. 0.0%
# PID: 0 nulls i.e. 0.0%
# MS SubClass: 0 nulls i.e. 0.0%
# MS Zoning: 0 nulls i.e. 0.0%
# Lot Frontage: 490 nulls i.e. 16.72%
# Lot Area: 0 nulls i.e. 0.0%
# Street: 0 nulls i.e. 0.0%
# Alley: 2732 nulls i.e. 93.24%
# Lot Shape: 0 nulls i.e. 0.0%
# Land Contour: 0 nulls i.e. 0.0%
# Utilities: 0 nulls i.e. 0.0%
# Lot Config: 0 nulls i.e. 0.0%
# Land Slope: 0 nulls i.e. 0.0%
# Neighborhood: 0 nulls i.e. 0.0%
# Condition 1: 0 nulls i.e. 0.0%
# Condition 2: 0 nulls i.e. 0.0%
# Bldg Type: 0 nulls i.e. 0.0%
# House Style: 0 nulls i.e. 0.0%
# Overall Qual: 0 nulls i.e. 0.0%
# Overall Cond: 0 nulls i.e. 0.0%
# Year Built: 0 nulls i.e. 0.0%
# Year Remod/Add: 0 nulls i.e. 0.0%
# Roof Style: 0 nulls i.e. 0.0%
# Roof Matl: 0 nulls i.e. 0.0%
# Exterior 1st: 0 nulls i.e. 0.0%
# Exterior 2nd: 0 nulls i.e. 0.0%
# Mas Vnr Type: 1775 nulls i.e. 60.58%
# Mas Vnr Area: 23 nulls i.e. 0.78%
# Exter Qual: 0 nulls i.e. 0.0%
# Exter Cond: 0 nulls i.e. 0.0%
# ...

# %%
df.drop(['Alley', 'Pool QC', 'Misc Feature', 'Fence', 'Fireplace Qu'], axis=1, inplace=True)
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Lot Shape Land Contour Utilities  ... Enclosed Porch 3Ssn Porch  \
# 0       IR1          Lvl    AllPub  ...              0          0
# 1       Reg          Lvl    AllPub  ...              0          0
# 2       IR1          Lvl    AllPub  ...              0          0
# 3       Reg          Lvl    AllPub  ...              0          0
# 4       IR1          Lvl    AllPub  ...              0          0
#
#   Screen Porch Pool Area Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# ...

# %%
cols_with_null = []
rows_count = df.shape[0]
for col in df.columns:
    null_count = df[col].isnull().sum()
    if null_count > 0:
        cols_with_null.append(col)
        print(f'{col}: {null_count} nulls i.e. {round(null_count/rows_count * 100, 2)}%')

print(cols_with_null)
# Out:
# Lot Frontage: 490 nulls i.e. 16.72%
# Mas Vnr Type: 1775 nulls i.e. 60.58%
# Mas Vnr Area: 23 nulls i.e. 0.78%
# Bsmt Qual: 80 nulls i.e. 2.73%
# Bsmt Cond: 80 nulls i.e. 2.73%
# Bsmt Exposure: 83 nulls i.e. 2.83%
# BsmtFin Type 1: 80 nulls i.e. 2.73%
# BsmtFin SF 1: 1 nulls i.e. 0.03%
# BsmtFin Type 2: 81 nulls i.e. 2.76%
# BsmtFin SF 2: 1 nulls i.e. 0.03%
# Bsmt Unf SF: 1 nulls i.e. 0.03%
# Total Bsmt SF: 1 nulls i.e. 0.03%
# Electrical: 1 nulls i.e. 0.03%
# Bsmt Full Bath: 2 nulls i.e. 0.07%
# Bsmt Half Bath: 2 nulls i.e. 0.07%
# Garage Type: 157 nulls i.e. 5.36%
# Garage Yr Blt: 159 nulls i.e. 5.43%
# Garage Finish: 159 nulls i.e. 5.43%
# Garage Cars: 1 nulls i.e. 0.03%
# Garage Area: 1 nulls i.e. 0.03%
# Garage Qual: 159 nulls i.e. 5.43%
# Garage Cond: 159 nulls i.e. 5.43%
# ...

# %%
df[cols_with_null].dtypes
# Out:
# Lot Frontage      float64
# Mas Vnr Type       object
# Mas Vnr Area      float64
# Bsmt Qual          object
# Bsmt Cond          object
# Bsmt Exposure      object
# BsmtFin Type 1     object
# BsmtFin SF 1      float64
# BsmtFin Type 2     object
# BsmtFin SF 2      float64
# Bsmt Unf SF       float64
# Total Bsmt SF     float64
# Electrical         object
# Bsmt Full Bath    float64
# Bsmt Half Bath    float64
# Garage Type        object
# Garage Yr Blt     float64
# Garage Finish      object
# Garage Cars       float64
# Garage Area       float64
# Garage Qual        object
# Garage Cond        object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Handling NAN

# %%
sns.histplot(data=df, x='Mas Vnr Type')
# Out:
# <Axes: xlabel='Mas Vnr Type', ylabel='Count'>

# %%
df['Mas Vnr Type'].unique()
# Out:
# array(['Stone', nan, 'BrkFace', 'BrkCmn', 'CBlock'], dtype=object)

# %%
df['Mas Vnr Type'] = df['Mas Vnr Type'].fillna('Unknown')
df['Mas Vnr Type'].isnull().sum()
# Out:
# C:\Users\Dmm\AppData\Local\Temp\ipykernel_2992\1997566019.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mas Vnr Type'].fillna('Unknown', inplace=True)
# np.int64(0)

# %%
cols_with_null.remove('Mas Vnr Type')
cols_with_null
# Out:
# ['Lot Frontage',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Electrical',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond']

# %%
for colname in cols_with_null:
    print(f'{colname}: {df[colname].unique()} \n {'-'*20}')
# Out:
# Lot Frontage: [141.  80.  81.  93.  74.  78.  41.  43.  39.  60.  75.  nan  63.  85.
#   47. 152.  88. 140. 105.  65.  70.  26.  21.  53.  24. 102.  98.  83.
#   94.  95.  90.  79. 100.  44. 110.  61.  36.  67. 108.  59.  92.  58.
#   56.  73.  72.  84.  76.  50.  55.  68. 107.  25.  30.  57.  40.  77.
#  120. 137.  87. 119.  64.  96.  71.  69.  52.  51.  54.  86. 124.  82.
#   38.  48.  89.  66.  45.  35. 129.  31.  42.  28.  99. 104.  97. 103.
#   34. 117. 149. 122.  62. 174. 106. 112.  32. 115. 128.  91.  33. 121.
#  144. 130. 109. 150. 113. 125. 101.  46. 114. 135. 136.  37.  22. 313.
#   49. 123. 160. 195. 118. 134. 182. 116. 138. 155. 126. 200. 168. 111.
#  131. 153. 133.]
#  --------------------
# Mas Vnr Area: [1.120e+02 0.000e+00 1.080e+02 2.000e+01 6.030e+02 3.500e+02 1.190e+02
#  4.800e+02 8.100e+01 1.800e+02 5.040e+02 4.920e+02 3.810e+02 1.620e+02
#  2.000e+02 4.500e+02 2.560e+02 2.260e+02 6.150e+02 2.400e+02 1.680e+02
# ...

# %% [markdown]
# - Do values imputation and move forward.

# %%
df['Lot Frontage'].isnull().sum()
# Out:
# np.int64(490)

# %%
sns.histplot(data=df, x='Lot Frontage')
plt.show()

# %%
df['Lot Frontage'].describe()
# Out:
# count    2440.000000
# mean       69.224590
# std        23.365335
# min        21.000000
# 25%        58.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: Lot Frontage, dtype: float64

# %%
df['Lot Frontage'] = df['Lot Frontage'].fillna(df['Lot Frontage'].mean())
df['Lot Frontage'].isnull().sum()

# %%
df['Mas Vnr Area'].isnull().sum()
# Out:
# np.int64(23)

# %%
sns.histplot(data=df, x='Mas Vnr Area')
plt.show()

# %%
df['Lot Frontage'].describe()
# Out:
# count    2930.000000
# mean       69.224590
# std        21.321523
# min        21.000000
# 25%        60.000000
# 50%        69.224590
# 75%        78.000000
# max       313.000000
# Name: Lot Frontage, dtype: float64

# %%
df['Mas Vnr Area'] = df['Mas Vnr Area'].fillna(df['Mas Vnr Area'].mean())
df['Mas Vnr Area'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Bsmt Qual'].isnull().sum()
# Out:
# np.int64(80)

# %%
df['Bsmt Qual'].value_counts()
# Out:
# Bsmt Qual
# TA    1283
# Gd    1219
# Ex     258
# Fa      88
# Po       2
# Name: count, dtype: int64

# %%
df['Bsmt Qual'] = df['Bsmt Qual'].fillna(df['Bsmt Qual'].mode()[0])
df['Bsmt Qual'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Bsmt Qual'].value_counts()
# Out:
# Bsmt Qual
# TA    1363
# Gd    1219
# Ex     258
# Fa      88
# Po       2
# Name: count, dtype: int64

# %%
df['Bsmt Cond'].isnull().sum()
# Out:
# np.int64(80)

# %%
df['Bsmt Cond'].value_counts()
# Out:
# Bsmt Cond
# TA    2616
# Gd     122
# Fa     104
# Po       5
# Ex       3
# Name: count, dtype: int64

# %%
df['Bsmt Cond'] = df['Bsmt Cond'].fillna(df['Bsmt Cond'].mode()[0])
df['Bsmt Cond'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Bsmt Exposure'].isnull().sum()
# Out:
# np.int64(83)

# %%
df['Bsmt Exposure'].value_counts()
# Out:
# Bsmt Exposure
# No    1906
# Av     418
# Gd     284
# Mn     239
# Name: count, dtype: int64

# %%
df['Bsmt Exposure'] = df['Bsmt Exposure'].fillna(df['Bsmt Exposure'].mode()[0])
df['Bsmt Exposure'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['BsmtFin Type 1'].isnull().sum()
# Out:
# np.int64(80)

# %%
df['BsmtFin Type 1'] = df['BsmtFin Type 1'].fillna(df['BsmtFin Type 1'].mode()[0])
df['BsmtFin Type 1'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['BsmtFin Type 2'].isnull().sum()
# Out:
# np.int64(81)

# %%
df['BsmtFin Type 2'] = df['BsmtFin Type 2'].fillna(df['BsmtFin Type 2'].mode()[0])
df['BsmtFin Type 2'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['BsmtFin SF 1'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['BsmtFin SF 1'].describe()
# Out:
# count    2929.000000
# mean      442.629566
# std       455.590839
# min         0.000000
# 25%         0.000000
# 50%       370.000000
# 75%       734.000000
# max      5644.000000
# Name: BsmtFin SF 1, dtype: float64

# %%
df['BsmtFin SF 1'] = df['BsmtFin SF 1'].fillna(df['BsmtFin SF 1'].median())
df['BsmtFin SF 1'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['BsmtFin SF 2'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['BsmtFin SF 2'] = df['BsmtFin SF 2'].fillna(df['BsmtFin SF 2'].median())
df['BsmtFin SF 2'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null
# Out:
# ['Lot Frontage',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Electrical',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond']

# %%
df['Bsmt Unf SF'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Bsmt Unf SF'].dtype
# Out:
# dtype('float64')

# %%
df['Bsmt Unf SF'] = df['Bsmt Unf SF'].fillna(df['Bsmt Unf SF'].median())
df['Bsmt Unf SF'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null.index('Bsmt Unf SF')
# Out:
# 9

# %%
cols_with_null[10]
# Out:
# 'Total Bsmt SF'

# %%
df['Total Bsmt SF'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Total Bsmt SF'].dtype
# Out:
# dtype('float64')

# %%
df['Total Bsmt SF'] = df['Total Bsmt SF'].fillna(df['Total Bsmt SF'].median())
df['Total Bsmt SF'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[11]
# Out:
# 'Electrical'

# %%
df['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseA', 'FuseF', 'FuseP', nan, 'Mix'], dtype=object)

# %%
df['Electrical'].mode()
# Out:
# 0    SBrkr
# Name: Electrical, dtype: object

# %%
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])
df['Electrical'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[12]
# Out:
# 'Bsmt Full Bath'

# %%
df['Bsmt Full Bath'].unique()
# Out:
# array([1., 0., 2., 3.])

# %%
df['Bsmt Full Bath'].isnull().sum()
# Out:
# np.int64(2)

# %%
df['Bsmt Full Bath'].mode()[0]
# Out:
# np.float64(0.0)

# %%
df['Bsmt Full Bath'] = df['Bsmt Full Bath'].fillna(df['Bsmt Full Bath'].mode()[0])
df['Bsmt Full Bath'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.histplot(df['Bsmt Full Bath'])
# Out:
# <Axes: xlabel='Bsmt Full Bath', ylabel='Count'>

# %%
cols_with_null[13]
# Out:
# 'Bsmt Half Bath'

# %%
df['Bsmt Half Bath'].isnull().sum()
# Out:
# np.int64(2)

# %%
df['Bsmt Half Bath'] = df['Bsmt Half Bath'].fillna(df['Bsmt Half Bath'].mode()[0])
df['Bsmt Half Bath'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[14]
# Out:
# 'Garage Type'

# %%
df['Garage Type'].isnull().sum()
# Out:
# np.int64(157)

# %%
df['Garage Type'].unique()
# Out:
# array(['Attchd', 'BuiltIn', 'Basment', 'Detchd', nan, 'CarPort', '2Types'],
#       dtype=object)

# %%
df['Garage Type'].mode()
# Out:
# 0    Attchd
# Name: Garage Type, dtype: object

# %%
df['Garage Type'] = df['Garage Type'].fillna(df['Garage Type'].mode()[0])
df['Garage Type'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[15]
# Out:
# 'Garage Yr Blt'

# %%
df['Garage Yr Blt'].isnull().sum()
# Out:
# np.int64(159)

# %%
df['Garage Yr Blt'].value_counts()
# Out:
# Garage Yr Blt
# 2005.0    142
# 2006.0    115
# 2007.0    115
# 2004.0     99
# 2003.0     92
#          ...
# 1908.0      1
# 1933.0      1
# 2207.0      1
# 1943.0      1
# 1919.0      1
# Name: count, Length: 103, dtype: int64

# %%
df['Garage Yr Blt'].unique()
# Out:
# array([1960., 1961., 1958., 1968., 1997., 1998., 2001., 1992., 1995.,
#        1999., 1993., 1990., 1985., 2003., 1988., 2010., 1951., 1978.,
#        1977., 1974., 2000., 1970., 1971.,   nan, 1975., 2009., 2008.,
#        2005., 2004., 2002., 2006., 1996., 1994., 1980., 1979., 1984.,
#        1986., 1920., 1987., 1973., 1963., 1962., 1976., 1967., 1972.,
#        1966., 1964., 1950., 1949., 1954., 1955., 1959., 1957., 1956.,
#        1952., 1953., 1989., 1948., 1900., 1927., 1915., 1945., 1940.,
#        1938., 1928., 1930., 1926., 1939., 1942., 1923., 1917., 1910.,
#        1965., 1969., 1947., 1946., 1941., 1924., 1922., 1896., 2007.,
#        1983., 1981., 1991., 1982., 1916., 1925., 1936., 1935., 1931.,
#        1934., 1929., 1918., 1921., 1937., 1932., 1906., 1908., 1895.,
#        1933., 2207., 1914., 1943., 1919.])

# %%
df['Garage Yr Blt'].mode()
# Out:
# 0    2005.0
# Name: Garage Yr Blt, dtype: float64

# %%
df['Garage Yr Blt'] = df['Garage Yr Blt'].fillna(df['Garage Yr Blt'].mode()[0])
df['Garage Yr Blt'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[16]
# Out:
# 'Garage Finish'

# %%
df['Garage Finish'].isnull().sum()
# Out:
# np.int64(159)

# %%
df['Garage Finish'].unique()
# Out:
# array(['Fin', 'Unf', 'RFn', nan], dtype=object)

# %%
df['Garage Finish'] = df['Garage Finish'].fillna(df['Garage Finish'].mode()[0])
df['Garage Finish'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[17]
# Out:
# 'Garage Cars'

# %%
df['Garage Cars'].unique()
# Out:
# array([ 2.,  1.,  3.,  0.,  4.,  5., nan])

# %%
df['Garage Cars'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Garage Cars'] = df['Garage Cars'].fillna(df['Garage Cars'].mode()[0])
df['Garage Cars'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[18]
# Out:
# 'Garage Area'

# %%
df['Garage Area'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Garage Area'].unique()
# Out:
# array([ 528.,  730.,  312.,  522.,  482.,  470.,  582.,  506.,  608.,
#         442.,  440.,  420.,  393.,  841.,  492.,  834.,  400.,  500.,
#         546.,  663.,  480.,  304.,  525.,    0.,  511.,  264.,  320.,
#         308.,  751.,  772.,  606.,  868.,  532.,  678.,  820.,  484.,
#         958.,  756.,  576.,  474.,  430.,  437.,  433.,  434.,  779.,
#         962.,  527.,  712.,  671.,  486.,  666.,  880.,  676.,  614.,
#         750.,  618.,  463.,  462.,  457.,  476.,  429.,  539.,  336.,
#         280.,  260.,  461.,  564.,  762.,  713.,  588.,  496.,  852.,
#         592.,  475.,  596.,  535.,  660.,  441.,  490.,  504.,  517.,
#         240.,  364.,  244.,  315.,  578.,  620.,  447.,  294.,  531.,
#         263.,  318.,  305.,  246.,  392.,  330.,  720.,  360.,  551.,
#         379.,  220.,  780.,  288.,  416.,  624.,  923.,  560.,  363.,
#         200.,  572.,  180.,  516.,  672.,  349.,  365.,  231.,  450.,
# ...

# %%
sns.histplot(df['Garage Area'])
# Out:
# <Axes: xlabel='Garage Area', ylabel='Count'>

# %%
df['Garage Area'].describe()
# Out:
# count    2929.000000
# mean      472.819734
# std       215.046549
# min         0.000000
# 25%       320.000000
# 50%       480.000000
# 75%       576.000000
# max      1488.000000
# Name: Garage Area, dtype: float64

# %%
df['Garage Area'] = df['Garage Area'].fillna(df['Garage Area'].mean())
df['Garage Area'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[19]
# Out:
# 'Garage Qual'

# %%
df['Garage Qual'].isnull().sum()
# Out:
# np.int64(159)

# %%
df['Garage Qual'].unique()
# Out:
# array(['TA', nan, 'Fa', 'Gd', 'Ex', 'Po'], dtype=object)

# %%
df['Garage Qual'].mode()
# Out:
# 0    TA
# Name: Garage Qual, dtype: object

# %%
df['Garage Qual'] = df['Garage Qual'].fillna(df['Garage Qual'].mode()[0])
df['Garage Qual'].isnull().sum()
# Out:
# np.int64(0)

# %%
cols_with_null[20]
# Out:
# 'Garage Cond'

# %%
df['Garage Cond'].isnull().sum()
# Out:
# np.int64(159)

# %%
df['Garage Cond'].unique()
# Out:
# array(['TA', nan, 'Fa', 'Gd', 'Ex', 'Po'], dtype=object)

# %%
df['Garage Cond'] = df['Garage Cond'].fillna(df['Garage Cond'].mode()[0])
df['Garage Cond'].isnull().sum()
# Out:
# np.int64(0)

# %%
len(cols_with_null)
# Out:
# 21

# %%
cols_with_null
# Out:
# ['Lot Frontage',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Electrical',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond']

# %%
df.isnull().sum()
# Out:
# Order             0
# PID               0
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 77, dtype: int64

# %%
cols_with_null = []
rows_count = df.shape[0]
for col in df.columns:
    null_count = df[col].isnull().sum()
    if null_count > 0:
        cols_with_null.append(col)
        print(f'{col}: {null_count} nulls i.e. {round(null_count/rows_count * 100, 2)}%')

print(cols_with_null)
# Out:
# []

# %% [markdown]
# ### Handling Outliers

# %%
df.to_csv('datasets/without-na.csv', index=False)

# %%
obj_cols = [colname for colname in df.columns if df[colname].dtype == 'O']
num_cols = [colname for colname in df.columns if df[colname].dtype != 'O']

# %%
len(obj_cols)
# Out:
# 38

# %%
len(num_cols)
# Out:
# 39

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Lot Shape Land Contour Utilities  ... Enclosed Porch 3Ssn Porch  \
# 0       IR1          Lvl    AllPub  ...              0          0
# 1       Reg          Lvl    AllPub  ...              0          0
# 2       IR1          Lvl    AllPub  ...              0          0
# 3       Reg          Lvl    AllPub  ...              0          0
# 4       IR1          Lvl    AllPub  ...              0          0
#
#   Screen Porch Pool Area Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# ...

# %%
num_cols = [colname for colname in df.columns if df[colname].dtype != 'O']
for colname in num_cols:
    plt.title(colname)
    sns.histplot(data=df, x=colname)
    plt.show()

# %%
df = pd.read_csv('datasets/without-na.csv')

# %%
df.drop('PID', axis=1, inplace=True)

# %%
df.drop('Order', axis=1, inplace=True)

# %%
df['MS SubClass'].value_counts()
# Out:
# MS SubClass
# 20     1079
# 60      575
# 50      287
# 120     192
# 30      139
# 160     129
# 70      128
# 80      118
# 90      109
# 190      61
# 85       48
# 75       23
# 45       18
# 180      17
# 40        6
# 150       1
# Name: count, dtype: int64

# %%
df['MS SubClass'] = df['MS SubClass'].astype(str)

# %%
df['MS SubClass'].dtype
# Out:
# dtype('O')

# %%
df['Lot Frontage'].describe()
# Out:
# count    2930.000000
# mean       69.224590
# std        21.321523
# min        21.000000
# 25%        60.000000
# 50%        69.224590
# 75%        78.000000
# max       313.000000
# Name: Lot Frontage, dtype: float64

# %%
df[df['Lot Frontage'] >= 150]
# Out:
#      MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 16            50        RL         152.0     12134   Pave       IR1
# 495           60        RL         174.0     15138   Pave       IR1
# 956           20        RL         150.0    215245   Pave       IR3
# 1265          20        RL         313.0     27650   Pave       IR2
# 1498          60        RL         313.0     63887   Pave       IR3
# 1592          85        RL         150.0     14137   Pave       Reg
# 1630          20        RL         160.0     18160   Grvl       Reg
# 1638         190        RL         195.0     41600   Pave       IR1
# 1745          20        RL         182.0     14572   Pave       IR3
# 1760          60        RL         160.0     15623   Pave       IR1
# 2118          20        RL         155.0     20064   Pave       IR1
# 2278          20        RL         200.0     43500   Pave       Reg
# 2321          60        RL         168.0     23257   Pave       IR3
# ...

# %% [markdown]
# We'll be removing these 16 rows

# %%
df = df[df['Lot Frontage'] <= 150]
df.shape
# Out:
# (2916, 75)

# %%
df['Lot Frontage'].describe()
# Out:
# count    2916.000000
# mean       68.645079
# std        19.323129
# min        21.000000
# 25%        60.000000
# 50%        69.224590
# 75%        78.000000
# max       150.000000
# Name: Lot Frontage, dtype: float64

# %%
df['Lot Area'].describe()
# Out:
# count      2916.000000
# mean      10078.288409
# std        7765.561020
# min        1300.000000
# 25%        7433.250000
# 50%        9400.000000
# 75%       11500.000000
# max      215245.000000
# Name: Lot Area, dtype: float64

# %%
df[df['Lot Area'] >= 30000]
# Out:
#      MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0             20        RL     141.00000     31770   Pave       IR1
# 15            60        RL      47.00000     53504   Pave       IR2
# 314           20        RL      69.22459     57200   Pave       IR1
# 504           60        RL      52.00000     46589   Pave       IR2
# 956           20        RL     150.00000    215245   Pave       IR3
# 1013          20        RL      69.22459     31220   Pave       IR1
# 1015          20        RL      69.22459     47280   Pave       IR1
# 1401          20        RL      73.00000     39104   Pave       IR1
# 1402          20        RL      69.22459     53227   Pave       IR1
# 1406          50        RL      75.00000     45600   Pave       IR2
# 1497          20        RL     123.00000     47007   Pave       IR1
# 1570         190        RL      69.22459    164660   Grvl       IR1
# 1610          70   I (all)      69.22459     56600   Pave       IR1
# ...

# %%
import numpy as np

def calc_lb_ub(column: pd.Series) -> tuple[float | float]:
    q1, q3 = np.quantile(column, [.25, .75])
    iqr = q3 - q1
    lb = q1 - 1.5 * iqr
    ub = q3 + 1.5 * iqr
    return (lb, ub)

lot_area_lb, lot_area_ub = calc_lb_ub(df['Lot Area'])
print()

# %%
df[df['Lot Area'] >= 17600].shape
# Out:
# (120, 75)

# %%
df[df['Lot Area'] >= 20000].shape
# Out:
# (83, 75)

# %% [markdown]
# We already have less samples in the dataset, I'll keep the upper bound to 20,000.

# %%
df = df[df['Lot Area'] <= 20000]

# %%
df.shape
# Out:
# (2833, 75)

# %%
df['Overall Qual'] = df['Overall Qual'].astype(str)

# %%
df['Overall Cond'] = df['Overall Cond'].astype(str)

# %%
df['Year Built'].value_counts()
# Out:
# Year Built
# 2005    139
# 2006    136
# 2007    107
# 2004     98
# 2003     87
#        ...
# 1893      1
# 1911      1
# 1879      1
# 1913      1
# 1908      1
# Name: count, Length: 118, dtype: int64

# %%
df['Year Built'] = df['Year Built'].astype(str)

# %% [markdown]
# Columns requiring encoding are getting converted to str (object) dtype.

# %%
df['Mas Vnr Area'].describe()
# Out:
# count    2833.000000
# mean       99.717518
# std       171.410321
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       163.000000
# max      1600.000000
# Name: Mas Vnr Area, dtype: float64

# %%
df[df['Mas Vnr Area'] >= 500]['Mas Vnr Area']
# Out:
# 29       504.0
# 41       615.0
# 44       760.0
# 46      1095.0
# 65       579.0
#          ...
# 2585     522.0
# 2607    1047.0
# 2762     532.0
# 2894     653.0
# 2899     630.0
# Name: Mas Vnr Area, Length: 111, dtype: float64

# %%
calc_lb_ub(df['Mas Vnr Area'])
# Out:
# (np.float64(-244.5), np.float64(407.5))

# %% [markdown]
# The Upper bound is 407. Let's use 420

# %%
df[df['Mas Vnr Area'] >= 420]['Mas Vnr Area']
# Out:
# 20      480.0
# 29      504.0
# 30      492.0
# 38      450.0
# 41      615.0
#         ...
# 2868    459.0
# 2883    473.0
# 2894    653.0
# 2899    630.0
# 2906    443.0
# Name: Mas Vnr Area, Length: 180, dtype: float64

# %%
df = df[df['Mas Vnr Area'] <= 420]
df.shape
# Out:
# (2660, 75)

# %%
df['Mas Vnr Area'].describe()
# Out:
# count    2660.000000
# mean       67.166816
# std       106.993913
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       120.000000
# max       420.000000
# Name: Mas Vnr Area, dtype: float64

# %%
sns.histplot(df['Mas Vnr Area'])
# Out:
# <Axes: xlabel='Mas Vnr Area', ylabel='Count'>

# %% [markdown]
# The column is following the power law, the reason of negative lower bound.

# %%
df['BsmtFin SF 1'].describe()
# Out:
# count    2660.000000
# mean      412.776316
# std       410.267484
# min         0.000000
# 25%         0.000000
# 50%       351.000000
# 75%       700.000000
# max      2158.000000
# Name: BsmtFin SF 1, dtype: float64

# %%
calc_lb_ub(df['BsmtFin SF 1'])
# Out:
# (np.float64(-1050.0), np.float64(1750.0))

# %%
df[df['BsmtFin SF 1'] >= 1750]['BsmtFin SF 1'].shape
# Out:
# (5,)

# %%
df = df[df['BsmtFin SF 1'] <= 1750]
df.shape
# Out:
# (2655, 75)

# %%
df['BsmtFin SF 2'].describe()
# Out:
# count    2655.000000
# mean       48.570245
# std       163.076233
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1474.000000
# Name: BsmtFin SF 2, dtype: float64

# %%
calc_lb_ub(df['BsmtFin SF 2'])
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
df['BsmtFin SF 2'].value_counts()
# Out:
# BsmtFin SF 2
# 0.0      2335
# 180.0       4
# 294.0       4
# 162.0       3
# 72.0        3
#          ...
# 547.0       1
# 173.0       1
# 396.0       1
# 324.0       1
# 123.0       1
# Name: count, Length: 256, dtype: int64

# %%
df[df['BsmtFin SF 2'] != 0.0].shape
# Out:
# (320, 75)

# %%
df['BsmtFin SF 2_0'] = (df['BsmtFin SF 2'] != 0.0).astype(int)

# %%
df['Bsmt Unf SF'].describe()
# Out:
# count    2655.000000
# mean      554.746139
# std       431.181627
# min         0.000000
# 25%       218.500000
# 50%       466.000000
# 75%       798.000000
# max      2140.000000
# Name: Bsmt Unf SF, dtype: float64

# %%
calc_lb_ub(df['Bsmt Unf SF'])
# Out:
# (np.float64(-650.75), np.float64(1667.25))

# %%
df[df['Bsmt Unf SF'] >= 1667].shape
# Out:
# (45, 76)

# %%
df = df[df['Bsmt Unf SF'] <= 1667]
df.shape
# Out:
# (2610, 76)

# %%
df['Bsmt Unf SF'].describe()
# Out:
# count    2610.000000
# mean      533.098851
# std       401.481801
# min         0.000000
# 25%       216.000000
# 50%       457.500000
# 75%       780.750000
# max      1664.000000
# Name: Bsmt Unf SF, dtype: float64

# %%
df['Total Bsmt SF'].describe()
# Out:
# count    2610.000000
# mean      999.032184
# std       373.857307
# min         0.000000
# 25%       780.000000
# 50%       960.000000
# 75%      1218.000000
# max      3206.000000
# Name: Total Bsmt SF, dtype: float64

# %%
calc_lb_ub(df['Total Bsmt SF'])
# Out:
# (np.float64(123.0), np.float64(1875.0))

# %%
df[(df['Total Bsmt SF'] <= 123) | (df['Total Bsmt SF'] >= 1875)].shape
# Out:
# (100, 76)

# %%
df = df[(df['Total Bsmt SF'] >= 123) | (df['Total Bsmt SF'] <= 1875)]
df.shape
# Out:
# (2610, 76)

# %%
df = df[df['Total Bsmt SF'] <= 1875]

# %%
df['Total Bsmt SF'].describe()
# Out:
# count    2582.000000
# mean      987.364059
# std       357.517067
# min         0.000000
# 25%       780.000000
# 50%       956.500000
# 75%      1211.250000
# max      1868.000000
# Name: Total Bsmt SF, dtype: float64

# %%
df.shape
# Out:
# (2582, 76)

# %%
df['1st Flr SF'].describe()
# Out:
# count    2582.000000
# mean     1096.578621
# std       315.169434
# min       334.000000
# 25%       864.000000
# 50%      1048.000000
# 75%      1302.000000
# max      2898.000000
# Name: 1st Flr SF, dtype: float64

# %%
calc_lb_ub(df['1st Flr SF'])
# Out:
# (np.float64(207.0), np.float64(1959.0))

# %%
df = df[df['1st Flr SF'] <= 1960]
df.shape
# Out:
# (2569, 76)

# %%
df['1st Flr SF'].describe()
# Out:
# count    2569.000000
# mean     1090.761386
# std       304.534818
# min       334.000000
# 25%       864.000000
# 50%      1044.000000
# 75%      1299.000000
# max      1960.000000
# Name: 1st Flr SF, dtype: float64

# %%
df['2nd Flr SF'].describe()
# Out:
# count    2569.000000
# mean      332.196964
# std       415.134990
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       700.000000
# max      1836.000000
# Name: 2nd Flr SF, dtype: float64

# %% [markdown]
# More than 50% values are 0.

# %%
calc_lb_ub(df['2nd Flr SF'])
# Out:
# (np.float64(-1050.0), np.float64(1750.0))

# %%
sns.histplot(data=df, x='2nd Flr SF', binwidth=100)
# Out:
# <Axes: xlabel='2nd Flr SF', ylabel='Count'>

# %%
df = df[df['2nd Flr SF'] <= 1300]
df.shape
# Out:
# (2527, 76)

# %%
df['Low Qual Fin SF'].describe()
# Out:
# count    2527.000000
# mean        4.837357
# std        46.834052
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1064.000000
# Name: Low Qual Fin SF, dtype: float64

# %%
df['Low Qual Fin SF_0'] = (df['Low Qual Fin SF'] == 0).astype(int)

# %%
df['Gr Liv Area'].describe()
# Out:
# count    2527.000000
# mean     1407.281361
# std       411.979035
# min       334.000000
# 25%      1092.000000
# 50%      1374.000000
# 75%      1656.000000
# max      3194.000000
# Name: Gr Liv Area, dtype: float64

# %%
calc_lb_ub(df['Gr Liv Area'])
# Out:
# (np.float64(246.0), np.float64(2502.0))

# %%
df = df[df['Gr Liv Area'] <= 2500]
df.shape
# Out:
# (2494, 77)

# %%
df['Bsmt Full Bath'] = df['Bsmt Full Bath'].astype(str)

# %%
df['Bsmt Half Bath'] = df['Bsmt Half Bath'].astype(str)

# %%
df['Full Bath'] = df['Full Bath'].astype(str)

# %%
df['Half Bath'] = df['Half Bath'].astype(str)

# %%
df['Bedroom AbvGr'] = df['Bedroom AbvGr'].astype(str)

# %%
df['Kitchen AbvGr'] = df['Kitchen AbvGr'].astype(str)

# %%
df['TotRms AbvGrd'] = df['TotRms AbvGrd'].astype(str)

# %%
df['Fireplaces'] = df['Fireplaces'].astype(str)

# %% [markdown]
# Converted the dtype of columns to encode them later

# %%
df['Garage Yr Blt'].describe()
# Out:
# count    2494.000000
# mean     1978.230152
# std        25.901414
# min      1895.000000
# 25%      1960.000000
# 50%      1980.000000
# 75%      2003.000000
# max      2207.000000
# Name: Garage Yr Blt, dtype: float64

# %%
calc_lb_ub(df['Garage Yr Blt'])
# Out:
# (np.float64(1895.5), np.float64(2067.5))

# %%
df[df['Garage Yr Blt'] > 2010]['Garage Yr Blt']
# Out:
# 2260    2207.0
# Name: Garage Yr Blt, dtype: float64

# %%
df = df[df['Garage Yr Blt'] < 2010]
df.shape
# Out:
# (2489, 77)

# %%
df['Garage Cars'] = df['Garage Cars'].astype(str)

# %%
df['Garage Area'].describe()
# Out:
# count    2489.000000
# mean      441.500932
# std       196.961349
# min         0.000000
# 25%       308.000000
# 50%       453.000000
# 75%       552.000000
# max      1488.000000
# Name: Garage Area, dtype: float64

# %%
calc_lb_ub(df['Garage Area'])
# Out:
# (np.float64(-58.0), np.float64(918.0))

# %%
sns.histplot(df['Garage Area'], binwidth=100)
# Out:
# <Axes: xlabel='Garage Area', ylabel='Count'>

# %%
df = df[df['Garage Area'] < 900]

# %%
df.shape
# Out:
# (2454, 77)

# %%
df['Garage Area'].describe()
# Out:
# count    2454.000000
# mean      433.624621
# std       186.294115
# min         0.000000
# 25%       308.000000
# 50%       450.000000
# 75%       545.750000
# max       898.000000
# Name: Garage Area, dtype: float64

# %%
df['Wood Deck SF'].describe()
# Out:
# count    2454.000000
# mean       83.721679
# std       116.472264
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       155.000000
# max      1424.000000
# Name: Wood Deck SF, dtype: float64

# %%
calc_lb_ub(df['Wood Deck SF'])
# Out:
# (np.float64(-232.5), np.float64(387.5))

# %%
sns.histplot(df['Wood Deck SF'], binwidth=50)
# Out:
# <Axes: xlabel='Wood Deck SF', ylabel='Count'>

# %%
df = df[df['Wood Deck SF'] < 400]
df.shape
# Out:
# (2401, 77)

# %%
df['Open Porch SF'].describe()
# Out:
# count    2401.000000
# mean       42.268222
# std        60.863554
# min         0.000000
# 25%         0.000000
# 50%        20.000000
# 75%        63.000000
# max       523.000000
# Name: Open Porch SF, dtype: float64

# %%
calc_lb_ub(df['Open Porch SF'])
# Out:
# (np.float64(-94.5), np.float64(157.5))

# %%
sns.histplot(df['Open Porch SF'], binwidth=50)
# Out:
# <Axes: xlabel='Open Porch SF', ylabel='Count'>

# %%
df = df[df['Open Porch SF'] < 150]
df.shape
# Out:
# (2239, 77)

# %%
df['Enclosed Porch'].describe()
# Out:
# count    2239.000000
# mean       23.733810
# std        60.455411
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       432.000000
# Name: Enclosed Porch, dtype: float64

# %%
sns.histplot(df['Enclosed Porch'], binwidth=50)
# Out:
# <Axes: xlabel='Enclosed Porch', ylabel='Count'>

# %%
calc_lb_ub(df['Enclosed Porch'])
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
df.drop('Enclosed Porch', axis=1, inplace=True)
# Out:
# C:\Users\Dmm\AppData\Local\Temp\ipykernel_2992\3178762349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Enclosed Porch', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street',
#        'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope',
#        'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Garage Type',
# ...

# %%
df['3Ssn Porch'].describe()
# Out:
# count    2239.000000
# mean        2.424297
# std        24.654837
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       508.000000
# Name: 3Ssn Porch, dtype: float64

# %%
calc_lb_ub(df['3Ssn Porch'])
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
df = df.drop('3Ssn Porch', axis=1)

# %%
df['Screen Porch'].describe()
# Out:
# count    2239.000000
# mean       14.724877
# std        53.016237
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       576.000000
# Name: Screen Porch, dtype: float64

# %%
calc_lb_ub(df['Screen Porch'])
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
df = df.drop('Screen Porch', axis=1)

# %%
df['Pool Area'].unique()
# Out:
# array([  0, 576, 368, 648])

# %%
df[df['Pool Area'] == 0]['SalePrice']
# Out:
# 1       105000
# 2       172000
# 4       189900
# 5       195500
# 6       213500
#          ...
# 2925    142500
# 2926    131000
# 2927    132000
# 2928    170000
# 2929    188000
# Name: SalePrice, Length: 2236, dtype: int64

# %%
df[df['Pool Area'] == 648]['SalePrice']
# Out:
# 2357    181000
# Name: SalePrice, dtype: int64

# %%
df = df.drop('Pool Area', axis=1)

# %% [markdown]
# The difference in price is not much. So dropping could be a good strategy.

# %%
df = df.drop('Misc Val', axis=1)

# %%
df['Mo Sold'] = df['Mo Sold'].astype(str)

# %%
df['Yr Sold'] = df['Yr Sold'].astype(str)

# %%
calc_lb_ub(df['SalePrice'])
# Out:
# (np.float64(29750.0), np.float64(283750.0))

# %%
df.shape
# Out:
# (2239, 72)

# %%
df[df['SalePrice'] < 300000].shape
# Out:
# (2187, 72)

# %%
df.to_csv('datasets/without-ols.csv', index=False)

# %%
num_cols = [colname for colname in df.columns if df[colname].dtype != 'O']
for colname in num_cols:
    plt.title(colname)
    sns.histplot(data=df, x=colname)
    plt.show()
